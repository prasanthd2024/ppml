# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({'A': ['sai', 'sai', 'subu', 'yuvi', 'rithi', 'subu'],
'B': ['one', 'one', 'three', 'one', 'three', 'three'],
'C': np.random.randint(5, size=6),
'D': np.random.randint(5, size=6),
'E': np.random.randint(5, size=6)})
print("\nOriginal DataFrame\n",df)
# Out:
# Original DataFrame
#         A      B  C  D  E
# 0    sai    one  2  1  2
# 1    sai    one  1  3  1
# 2   subu  three  0  2  2
# 3   yuvi    one  3  1  4
# 4  rithi  three  0  2  2
# 5   subu  three  3  0  1

# %%
#Group by (multi-column): with one column sum
df1 = df.groupby(['A', 'B'], as_index=False)['C'].sum()
print("\nOriginal DataFrame\n",df)
print("\nGroup by (multi-column): with one column sum\n",df1)
# Out:
# Original DataFrame
#         A      B  C  D  E
# 0    sai    one  2  1  2
# 1    sai    one  1  3  1
# 2   subu  three  0  2  2
# 3   yuvi    one  3  1  4
# 4  rithi  three  0  2  2
# 5   subu  three  3  0  1
#
# Group by (multi-column): with one column sum
#         A      B  C
# 0  rithi  three  0
# 1    sai    one  3
# 2   subu  three  3
# 3   yuvi    one  3

# %%
#Group by (multi-column): with multi column sum
df2 = df.groupby(['A', 'B'], as_index=False).sum()
print("\nOriginal DataFrame\n",df)
print("\nGroup by (multi-column): with multi columns sum\n",df2)
# Out:
# Original DataFrame
#         A      B  C  D  E
# 0    sai    one  2  1  2
# 1    sai    one  1  3  1
# 2   subu  three  0  2  2
# 3   yuvi    one  3  1  4
# 4  rithi  three  0  2  2
# 5   subu  three  3  0  1
#
# Group by (multi-column): with multi columns sum
#         A      B  C  D  E
# 0  rithi  three  0  2  2
# 1    sai    one  3  4  3
# 2   subu  three  3  2  3
# 3   yuvi    one  3  1  4

# %%
#combined groupby and aggregate function
df3 = df.groupby(['A', 'B'], as_index=False)['C'].agg('sum')
print("\nOriginal DataFrame\n",df)
print("\nCombined Groupby and Aggregate function\n",df3)
# Out:
# Original DataFrame
#         A      B  C  D  E
# 0    sai    one  2  1  2
# 1    sai    one  1  3  1
# 2   subu  three  0  2  2
# 3   yuvi    one  3  1  4
# 4  rithi  three  0  2  2
# 5   subu  three  3  0  1
#
# Combined Groupby and Aggregate function
#         A      B  C
# 0  rithi  three  0
# 1    sai    one  3
# 2   subu  three  3
# 3   yuvi    one  3

# %%
df4 = (df.groupby(['A', 'B']).agg([('average', 'mean'), ('total', 'sum')]))
print("\nOriginal DataFrame\n",df)
print("\nCombined Groupby and Aggregate function-separate column headings\n",df4)
# Out:
# Original DataFrame
#         A      B  C  D  E
# 0    sai    one  2  1  2
# 1    sai    one  1  3  1
# 2   subu  three  0  2  2
# 3   yuvi    one  3  1  4
# 4  rithi  three  0  2  2
# 5   subu  three  3  0  1
#
# Combined Groupby and Aggregate function-separate column headings
#                    C             D             E
#             average total average total average total
# A     B
# rithi three     0.0     0     2.0     2     2.0     2
# sai   one       1.5     3     2.0     4     1.5     3
# subu  three     1.5     3     1.0     2     1.5     3
# yuvi  one       3.0     3     1.0     1     4.0     4

# %%
df5 = df.groupby(['A', 'B'], as_index=False).sum()
df6 = (df.groupby(['A', 'B']).agg(['sum']))
print("\nOriginal DataFrame\n",df)
print("\nGroupby-sum function\n",df5)
print("\nGroupby and Aggregate - sum function\n",df6)
# Out:
# Original DataFrame
#         A      B  C  D  E
# 0    sai    one  2  1  2
# 1    sai    one  1  3  1
# 2   subu  three  0  2  2
# 3   yuvi    one  3  1  4
# 4  rithi  three  0  2  2
# 5   subu  three  3  0  1
#
# Groupby-sum function
#         A      B  C  D  E
# 0  rithi  three  0  2  2
# 1    sai    one  3  4  3
# 2   subu  three  3  2  3
# 3   yuvi    one  3  1  4
#
# Groupby and Aggregate - sum function
#                C   D   E
#             sum sum sum
# A     B
# rithi three   0   2   2
# sai   one     3   4   3
# subu  three   3   2   3
# yuvi  one     3   1   4
