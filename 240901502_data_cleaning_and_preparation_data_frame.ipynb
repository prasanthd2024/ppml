# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe with NaN\n",df)
print("\n")
print("Dropped DataFrame\n",df.dropna())
print("\n")
# Out:
# Original Dataframe with NaN
#          one       two     three
# a -1.551510  0.525398  0.677269
# b       NaN       NaN       NaN
# c  2.034602 -0.268836  0.537155
# d -0.113067 -0.336053 -0.593982
# e       NaN       NaN       NaN
# f  0.013835  0.048811 -0.700798
#
#
# Dropped DataFrame
#          one       two     three
# a -1.551510  0.525398  0.677269
# c  2.034602 -0.268836  0.537155
# d -0.113067 -0.336053 -0.593982
# f  0.013835  0.048811 -0.700798

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c'])
print("Original Dataframe:\n",df)
print("\n")
print("NaN replaced with '0':\n")
print(df.fillna(0))
# Out:
# Original Dataframe:
#          one       two     three
# a  1.945228  1.386814  0.744728
# b       NaN       NaN       NaN
# c  1.002960  2.099530  0.430576
#
#
# NaN replaced with '0':
#
#         one       two     three
# a  1.945228  1.386814  0.744728
# b  0.000000  0.000000  0.000000
# c  1.002960  2.099530  0.430576

# %%
df=pd.DataFrame({'one':[10,20,80,40,50],
'two':[60,70,80,0,10]})
print("Original Dataframe:\n",df)
print("\n DataFrame with replaced values:\n")
print(df.replace({10:5,80:3}))
# Out:
# Original Dataframe:
#     one  two
# 0   10   60
# 1   20   70
# 2   80   80
# 3   40    0
# 4   50   10
#
#  DataFrame with replaced values:
#
#    one  two
# 0    5   60
# 1   20   70
# 2    3    3
# 3   40    0
# 4   50    5

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNan-with True fill:\n")
print(df['one'].isnull())
# Out:
# Original Dataframe:
#          one       two     three
# a  0.461717 -0.947792 -0.074544
# b       NaN       NaN       NaN
# c -0.850448  2.430184 -0.992581
# d  2.276536 -0.881999  3.148716
# e       NaN       NaN       NaN
# f -0.565791 -1.883482 -0.543852
#
# Nan-with True fill:
#
# a    False
# b     True
# c    False
# d    False
# e     True
# f    False
# Name: one, dtype: bool

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNaN - Filled with Background values:\n")
print(df.fillna(method='bfill'))
# Out:
# Original Dataframe:
#          one       two     three
# a -0.679645  0.773048 -2.303144
# b       NaN       NaN       NaN
# c  1.460190  0.354805 -1.300335
# d  1.380474  0.721080  0.590929
# e       NaN       NaN       NaN
# f  1.810868 -1.217976  0.592217
#
# NaN - Filled with Background values:
#
#         one       two     three
# a -0.679645  0.773048 -2.303144
# b  1.460190  0.354805 -1.300335
# c  1.460190  0.354805 -1.300335
# d  1.380474  0.721080  0.590929
# e  1.810868 -1.217976  0.592217
# f  1.810868 -1.217976  0.592217
# /tmp/ipykernel_5037/3060127685.py:6: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
