# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe with NaN\n",df)
print("\n")
print("Dropped DataFrame\n",df.dropna())
print("\n")
# Out:
# Original Dataframe with NaN
#          one       two     three
# a  0.194718  0.507033  0.775332
# b       NaN       NaN       NaN
# c -0.021573  1.405378  1.499354
# d -0.671190 -0.366379 -1.224156
# e       NaN       NaN       NaN
# f  0.372220 -0.036332 -0.073434
#
#
# Dropped DataFrame
#          one       two     three
# a  0.194718  0.507033  0.775332
# c -0.021573  1.405378  1.499354
# d -0.671190 -0.366379 -1.224156
# f  0.372220 -0.036332 -0.073434

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c'])
print("Original Dataframe:\n",df)
print("\n")
print("NaN replaced with '0':\n")
print(df.fillna(0))
# Out:
# Original Dataframe:
#          one       two     three
# a  0.678464 -1.052026 -0.322379
# b       NaN       NaN       NaN
# c -1.526732  1.320267 -0.795168
#
#
# NaN replaced with '0':
#
#         one       two     three
# a  0.678464 -1.052026 -0.322379
# b  0.000000  0.000000  0.000000
# c -1.526732  1.320267 -0.795168

# %%
df=pd.DataFrame({'one':[10,20,80,40,50],
'two':[60,70,80,0,10]})
print("Original Dataframe:\n",df)
print("\n DataFrame with replaced values:\n")
print(df.replace({10:5,80:3}))
# Out:
# Original Dataframe:
#     one  two
# 0   10   60
# 1   20   70
# 2   80   80
# 3   40    0
# 4   50   10
#
#  DataFrame with replaced values:
#
#    one  two
# 0    5   60
# 1   20   70
# 2    3    3
# 3   40    0
# 4   50    5

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNan-with True fill:\n")
print(df['one'].isnull())
# Out:
# Original Dataframe:
#          one       two     three
# a -0.644334 -2.016616  1.046287
# b       NaN       NaN       NaN
# c -1.541419 -1.205350 -0.120656
# d -1.280638  0.420076  0.359664
# e       NaN       NaN       NaN
# f  1.526499  0.738850  1.843302
#
# Nan-with True fill:
#
# a    False
# b     True
# c    False
# d    False
# e     True
# f    False
# Name: one, dtype: bool

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNaN - Filled with Background values:\n")
print(df.fillna(method='bfill'))
# Out:
# Original Dataframe:
#          one       two     three
# a  0.219175  2.196154  0.931999
# b       NaN       NaN       NaN
# c  0.606339  0.245786 -0.451448
# d -0.425916  0.117998 -0.080346
# e       NaN       NaN       NaN
# f  1.968144 -1.493326 -0.395133
#
# NaN - Filled with Background values:
#
#         one       two     three
# a  0.219175  2.196154  0.931999
# b  0.606339  0.245786 -0.451448
# c  0.606339  0.245786 -0.451448
# d -0.425916  0.117998 -0.080346
# e  1.968144 -1.493326 -0.395133
# f  1.968144 -1.493326 -0.395133
# /tmp/ipykernel_1527/1573768271.py:6: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   print(df.fillna(method='bfill'))
